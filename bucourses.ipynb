# %%
import pandas as pd 
import numpy as np 
import sys

# %%
#makes course code without sections 
def de_section(x):
    return x[:-3]

# %% [markdown]
# # Url

# %%
#makes url by using short name, term, department name
def make_url(term,short,long):
    init = 'https://registration.boun.edu.tr/scripts/sch.asp?donem='
    init2 = '&kisaadi='
    init3 = '&bolum='
    return init + year_format(term) + init2 + short + init3 + make_long(long)

# %% [markdown]
# ## Short & Long Name

# %%
short =['ASIA','ASIA','ATA','AUTO','BM','BIS','CHE',
        'CHEM','CE','COGS','CSE','CET','CMPE','INT',
        'CEM','CCS','EQE','EC','EF','ED','CET','EE',
        'ETM','ENV','ENVT','XMBE','FE','PA','FLED',
        'GED','GPH','GUID','HIST','HUM','IE','INCT',
        'MIR','MIR','INTT','INTT','LS','LING','AD',
        'MIS','MATH','SCED','ME','MECA','BIO','PHIL',
        'PE','PHYS','POLS','PRED','PSY','YADYOK','SCED',
        'SPL','SOC','SWE','SWE','TRM','SCO','TRM','WTR',
        'TR','TK','TKL','LL']

# %%
long = ['ASIAN STUDIES','ASIAN STUDIES WITH THESIS',
        'ATATURK INSTITUTE FOR MODERN TURKISH HISTORY',
        'AUTOMOTIVE ENGINEERING','BIOMEDICAL ENGINEERING',
        'BUSINESS INFORMATION SYSTEMS','CHEMICAL ENGINEERING',
        'CHEMISTRY','CIVIL ENGINEERING','COGNITIVE SCIENCE',
        'COMPUTATIONAL SCIENCE & ENGINEERING',
        'COMPUTER EDUCATION & EDUCATIONAL TECHNOLOGY',
        'COMPUTER ENGINEERING','CONFERENCE INTERPRETING',
        'CONSTRUCTION ENGINEERING AND MANAGEMENT',
        'CRITICAL AND CULTURAL STUDIES','EARTHQUAKE ENGINEERING',
        'ECONOMICS','ECONOMICS AND FINANCE','EDUCATIONAL SCIENCES',
        'EDUCATIONAL TECHNOLOGY','ELECTRICAL & ELECTRONICS ENGINEERING',
        'ENGINEERING AND TECHNOLOGY MANAGEMENT','ENVIRONMENTAL SCIENCES',
        'ENVIRONMENTAL TECHNOLOGY','EXECUTIVE MBA',
        'FINANCIAL ENGINEERING','FINE ARTS','FOREIGN LANGUAGE EDUCATION',
        'GEODESY','GEOPHYSICS','GUIDANCE & PSYCHOLOGICAL COUNSELING',
        'HISTORY','HUMANITIES COURSES COORDINATOR',
        'INDUSTRIAL ENGINEERING','INTERNATIONAL COMPETITION AND TRADE',
        'INTERNATIONAL RELATIONS:TURKEY;EUROPE AND THE MIDDLE EAST',
        'INTERNATIONAL RELATIONS:TURKEY;EUROPE AND THE MIDDLE EAST WITH THESIS',
        'INTERNATIONAL TRADE','INTERNATIONAL TRADE MANAGEMENT',
        'LEARNING SCIENCES','LINGUISTICS','MANAGEMENT',
        'MANAGEMENT INFORMATION SYSTEMS','MATHEMATICS',
        'MATHEMATICS AND SCIENCE EDUCATION','MECHANICAL ENGINEERING',
        'MECHATRONICS ENGINEERING','MOLECULAR BIOLOGY & GENETICS',
        'PHILOSOPHY','PHYSICAL EDUCATION','PHYSICS',
        'POLITICAL SCIENCE&INTERNATIONAL RELATIONS',
        'PRIMARY EDUCATION','PSYCHOLOGY','SCHOOL OF FOREIGN LANGUAGES',
        'SECONDARY SCHOOL SCIENCE AND MATHEMATICS EDUCATION',
        'SOCIAL POLICY WITH THESIS','SOCIOLOGY','SOFTWARE ENGINEERING',
        'SOFTWARE ENGINEERING WITH THESIS','SUSTAINABLE TOURISM MANAGEMENT',
        'SYSTEMS & CONTROL ENGINEERING','TOURISM ADMINISTRATION',
        'TRANSLATION','TRANSLATION AND INTERPRETING STUDIES',
        'TURKISH COURSES COORDINATOR','TURKISH LANGUAGE & LITERATURE',
        'WESTERN LANGUAGES & LITERATURES']

# %% [markdown]
# ### Sorting Departments' Abbreviation

# %%
short_long_df = pd.DataFrame([long,short])
short_long_df.sort_values(1,axis=1,inplace=True)
long = np.array(short_long_df.T[0])
short = np.array(short_long_df.T[1])

# %%
#transforms department names to proper long format for url 
def make_long(x):
    x = x.replace('&','%26')
    x = x.replace(':','%3a')
    x = x.replace(',','%2c')
    x = x.replace(' ','+')
    return x

# %% [markdown]
# ## Year

# %%
# encodes input terms to integer
def year_encoder(x):
    year = (int(x[:4])-1000)*3
    season = x[5:]
    if season == 'Fall':
        return year + 2
    if season == 'Spring':
        return year 
    if season == 'Summer':
        return year + 1
    
#decodes term & generates links 
def year_format(x):
    term = int(((x+1) % 3) + 1)
    year = int(((x-2) / 3) + 1000)
    return str(year) + '/' + str(year+1) + '-' + str(term)

#decodes term to original form
def year_original(x):
    term = int(((x+1) % 3) + 1)
    year = int(((x-2) / 3) + 1000)
    if(term == 1):
        return str(year) + '-' + 'Fall'
    if(term == 2):
        return str(year + 1) + '-' + 'Spring'
    if(term == 3):
        return str(year + 1) + '-' + 'Summer'

# %% [markdown]
# # Input

# %%
#start_term = sys.argv[1]
#end_term = sys.argv[2]
start_term = '2017-Fall' 
end_term = '2018-Spring'
start_date = year_encoder(start_term)
end_date = year_encoder(end_term)

# %% [markdown]
# # Crawling
# Crawles http://registration.boun.edu.tr/ and deducts dataframes

# %%
mask = ['Code.Sec',
        'Name',
        'Instr.']
info = pd.DataFrame(columns=['Term',
                             'Short',
                             'Long',
                             'Name',
                             'Code.Sec',
                             'Instr.'])
for term in np.arange(start_date,end_date+1):
    for i in range(3):
        url = make_url(term,
                       short[i],
                       long[i])
        try:
            temp_df = pd.read_html(url)
            temp_df = temp_df[3]
            t = temp_df
            t.rename(columns=t.loc[0],
                     inplace=True)
            t.drop(index=0,
                   inplace=True)
            t = t[mask]
            t = t.dropna()
            t.reset_index(inplace=True)
            new = pd.DataFrame(columns=['Term',
                                        'Short',
                                        'Long'])
            new = new.reindex(index=np.arange(len(t)))
            new[['Term',
                 'Short',
                 'Long']] = [term,
                             short[i],
                             long[i]]
            new[['Name',
                 'Code.Sec',
                 'Instr.']] = t[['Name',
                                 'Code.Sec',
                                 'Instr.']]
            info = pd.concat([new,
                              info])
        except:
            pass
info.reset_index(inplace=True)
info.drop(columns='index',
          inplace=True)
info['Code.Sec'] = (info['Code.Sec']
                    .apply(lambda x:de_section(x)))

# %% [markdown]
# # Information Retrieval From Each Department

# %%
final = pd.DataFrame()
for i in range(len(short)):
    
    #department dataframe from crawled data  
    dept = info[info['Short'] == short[i]]
    dept = dept.reset_index(drop=True)

    #title row for the department 
    title = pd.DataFrame(columns=['Dept./Prog.(name)',
                                  'Course Code',
                                  'Course Name'])
    
    #department courses' information 
    G = dept[dept['Code.Sec'].str[-3] > '4']
    G = G[G['Code.Sec'].str[-3] < '9']['Code.Sec'].nunique()
    total_course = dept['Code.Sec'].nunique()
    U = total_course - G
    title.loc[len(title)] = [short[i] + '(' + long[i] + ')',
                             'U' + str(U) + ' G' + str(G),
                             '']

    #table format for csv file 
    main = pd.DataFrame(columns=['Dept./Prog.(name)','Course Code','Course Name'])
    main[['Course Code','Course Name']] = dept[['Code.Sec','Name']]
    main = main.drop_duplicates(subset='Course Code',keep='first',inplace=False)
    main = main.sort_values('Course Code')
    main = main.reset_index(drop=True)

    res = pd.DataFrame(columns=['Dept./Prog.(name)','Course Code','Course Name'])
    res = pd.concat([title,main])
    res = res.replace(np.nan, '', regex=True)
    res = res.reset_index(drop=True)
    
    
    #Retrieves number of Grad and Undergrad courses
    total_U = 0
    total_G = 0
    total_I = (dept[dept['Instr.'] != 'STAFF STAFF']
               .nunique()['Instr.'])
    
    for term in np.arange(start_date,end_date+1):
        
        term_name = year_original(term)
        term_info = dept[dept['Term'] == term]

        
        #terms' courses information 
        term_title = pd.DataFrame(columns=[term_name])
        
        term_I = (term_info[term_info['Instr.'] != 'STAFF STAFF']
                  .nunique()['Instr.'])
        
        term_G = term_info[term_info['Code.Sec']
                           .str[-3] > '4']
        
        term_G = (term_G[term_G['Code.Sec']
                        .str[-3] < '9']
                  ['Code.Sec']
                  .nunique())
        
        term_Tot = (term_info
                    ['Code.Sec']
                    .nunique())
        
        term_U = term_Tot - term_G
        
        (term_title
         .loc[len(term_title)]) = ['U' +
                                   str(term_U) +
                                   ' G' +
                                   str(term_G) +
                                   ' I' +
                                   str(term_I)]
        
        
        term_main = pd.DataFrame(columns=[term_name])
        term_main[term_name] = main['Course Code']
        
        term_courses = pd.DataFrame(columns=[term_name])
        term_courses[term_name] = term_info['Code.Sec']
        term_courses = term_courses.drop_duplicates(subset=term_name,
                                                    keep='first',
                                                    inplace=False)
        term_courses = term_courses.reset_index(drop=True)
        
        #Indicates whether course opened or not in this semester
        term_main[term_name] = (np.where
                                ((term_main
                                  [term_name]
                                  .isin(term_courses[term_name]))
                                 ,'x',''))

        #calculates total number of grads and undergrads courses
        total_U = total_U + term_U
        total_G = total_G + term_G
        
        term_res = pd.DataFrame(columns=[term_name])
        term_res = pd.concat([term_title,
                              term_main])

        res[term_name] = term_res[term_name].values
        
        
    #Total Offering Information Retrieval 
    total_title = pd.DataFrame(columns=['Total Offerings'])
    total_title.loc[len(total_title)] = ['U' +
                                         str(total_U) +
                                         ' G' +
                                         str(total_G) +
                                         ' I' +
                                         str(total_I)]
    
    total_main = pd.DataFrame(columns=['Total Offerings'])
    total_main['Total Offerings'] = main['Course Code']
    (total_main['Total Offerings']) = (total_main['Total Offerings']
                                       .apply(lambda x:
                                              str(dept[dept['Code.Sec'] == x]
                                                  ['Term']
                                                  .nunique()) +
                                              '/' +
                                              str(dept[dept['Code.Sec'] == x]
                                                  ['Instr.']
                                                  .nunique())))
    
    total_res = pd.concat([total_title,
                           total_main])
    res['Total Offerings'] = (total_res['Total Offerings']
                              .values)
    
    final = pd.concat([final,
                       res])

# %%
#Last modification to write csv file.
final = final.reset_index(drop=True)
final = '"'+ final +'"'
final.set_index('Dept./Prog.(name)',inplace=True)
final.to_csv(sys.stdout)
# Out:
# Dept./Prog.(name),Course Code,Course Name,2017-Fall,2018-Spring,Total Offerings
# """AD(MANAGEMENT)""","""U49 G62""","""""","""U35 G43 I38""","""U32 G37 I36""","""U67 G80 I43"""
# """""","""AD 102""","""INTRODUCTION TO MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 131""","""INTRO. TO LAW I""","""x""","""x""","""2/1"""
# """""","""AD 204""","""BUSINESS COMMUNICATIONS""","""x""","""x""","""2/1"""
# """""","""AD 211""","""FINANCIAL ACCOUNTING FOR ECONOMISTS""","""x""","""x""","""2/2"""
# """""","""AD 213""","""FINANCIAL ACCOUNTING""","""x""","""""","""1/1"""
# """""","""AD 214""","""MANAGERIAL ACCOUNTING""","""""","""x""","""1/1"""
# """""","""AD 216""","""FINANCIAL & COST ACCOUNTING""","""x""","""""","""1/1"""
# """""","""AD 220""","""MANAGEMENT OF ORGANIZATIONS""","""x""","""x""","""2/3"""
# """""","""AD 231""","""BUSINESS LAW""","""x""","""""","""1/1"""
# """""","""AD 242""","""STRATEGIC MARKETING MANAGEMENT""","""""","""x""","""1/2"""
# """""","""AD 251""","""MANAGERIAL STATISTICS I""","""x""","""""","""1/2"""
# """""","""AD 252""","""MANAGERIAL STATISTICS II""","""""","""x""","""1/2"""
# """""","""AD 302""","""RESEARCH METHODS(G-Z)""","""x""","""x""","""2/2"""
# """""","""AD 311""","""FINANCIAL MANAGEMENT""","""x""","""x""","""2/3"""
# """""","""AD 312""","""MONEY & BANKING""","""""","""x""","""1/1"""
# """""","""AD 314""","""INTERMEDIATE FINANCIAL ACCOUNTING""","""""","""x""","""1/1"""
# """""","""AD 320""","""HUMAN RESOURCES MANAGEMENT(A-F)""","""x""","""x""","""2/1"""
# """""","""AD 351""","""OPERATIONS MANAGEMENT""","""x""","""x""","""2/2"""
# """""","""AD 353""","""MANAGEMENT SCIENCE""","""x""","""x""","""2/2"""
# """""","""AD 401""","""GLOBALIZATION&INTERNATIONAL MANAGEMENT(J-Z)""","""x""","""x""","""2/1"""
# """""","""AD 403""","""MANAGERIAL ECONOMICS""","""x""","""x""","""2/1"""
# """""","""AD 408""","""STRATEGIC MANAGEMENT""","""x""","""x""","""2/1"""
# """""","""AD 409""","""BUSINESS ETHICS""","""""","""x""","""1/1"""
# """""","""AD 411""","""FINANCE FOR CREATIVE INDUSTRIES""","""""","""x""","""1/1"""
# """""","""AD 413""","""AUDITING""","""""","""x""","""1/1"""
# """""","""AD 418""","""INTERNATIONAL FINANCE""","""""","""x""","""1/1"""
# """""","""AD 424""","""HUMAN BEHAVIOR IN ORGANIZATIONS""","""x""","""x""","""2/1"""
# """""","""AD 428""","""NGO MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 429""","""MANAGEMENT OF MULTINATIONALS""","""x""","""""","""1/1"""
# """""","""AD 430""","""TURKISH BUSINESS ENVIRONMENT""","""x""","""x""","""2/1"""
# """""","""AD 433""","""MANAGEMENT SIMULATION""","""x""","""""","""1/1"""
# """""","""AD 440""","""DIGITAL MARKETING""","""x""","""""","""1/1"""
# """""","""AD 441""","""CONSUMER BEHAVIOR""","""x""","""""","""1/1"""
# """""","""AD 444""","""SALES MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 448""","""BRAND MANAGEMENT""","""""","""x""","""1/1"""
# """""","""AD 451""","""MANAGEMENT OF CONSTRAINTS""","""x""","""""","""1/1"""
# """""","""AD 452""","""INFORMATION SYSTEMS MANAGEMENT""","""x""","""x""","""2/2"""
# """""","""AD 462""","""LEGAL ASPECTS OF INTELLEC. PROPERTY MAN.""","""""","""x""","""1/1"""
# """""","""AD 467""","""CORPORATE GOVERNANCE""","""x""","""""","""1/1"""
# """""","""AD 468""","""FINANCIAL RISK MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 470""","""INVESTMENT MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 472""","""FINANCIAL MARKETS&INSTITUTIONS""","""""","""x""","""1/1"""
# """""","""AD 477""","""BANK MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 480""","""SP.TOP.IN MANAGEMENT:CREATIVITY&LEADERS.""","""x""","""""","""1/1"""
# """""","""AD 487""","""SP.TP.CURRENT TRENDS IN SEL.INDUSTRIES""","""x""","""x""","""2/1"""
# """""","""AD 48A""","""SP.TP.:MARKETING IN FMCG""","""""","""x""","""1/1"""
# """""","""AD 495""","""SP.TOP. IN CORPORATE FINANCE""","""""","""x""","""1/1"""
# """""","""AD 496""","""SP.TOP. IN FINANCE""","""x""","""x""","""2/2"""
# """""","""AD 497""","""BACHELOR OF ARTS DEGREE PROJECT""","""x""","""x""","""2/1"""
# """""","""AD 501""","""TOPICS IN BUSINESS ECONOMICS""","""x""","""""","""1/1"""
# """""","""AD 504""","""RESEARCH METHODOLOGY""","""x""","""""","""1/1"""
# """""","""AD 507""","""STRATEGY""","""""","""x""","""1/1"""
# """""","""AD 509""","""GLOBAL CONTEXT OF BUSINESS""","""""","""x""","""1/1"""
# """""","""AD 510""","""MANAGEMENT OF ETHICAL ISSUES&SUSTAINABIL""","""""","""x""","""1/1"""
# """""","""AD 516""","""FINANCIAL DERIVATIVES""","""""","""x""","""1/1"""
# """""","""AD 517""","""INVESTMENT ANALYSIS & PORTFOLIO MGMT.""","""""","""x""","""1/1"""
# """""","""AD 520""","""CORPORATE STRATEGY/MANAGEMENT SIMULATION""","""x""","""""","""1/1"""
# """""","""AD 527""","""ORGANIZATIONAL BEHAVIOR&DESIGN""","""x""","""""","""1/1"""
# """""","""AD 540""","""STRATEGIC MARKETING MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 545""","""THEORY QUEST IN MARKETING""","""x""","""""","""1/1"""
# """""","""AD 547""","""SERVICE MARKETING""","""""","""x""","""1/1"""
# """""","""AD 550""","""OPERATIONS MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 551""","""INTRODUCTION OF THEORIES OF OPERATIONS M""","""x""","""""","""1/1"""
# """""","""AD 568""","""ACCOUNTING,INFORMATION&CONTROL SYSTEMS""","""x""","""""","""1/1"""
# """""","""AD 570""","""ACCOUNTING FOR MANAGERS""","""x""","""""","""1/1"""
# """""","""AD 573""","""FINANCIAL ECONOMETRICS""","""x""","""""","""1/1"""
# """""","""AD 576""","""CONTEMPORARY FINANCIAL MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 577""","""FINANCIAL THEORY&CORPORATE POLICY""","""x""","""""","""1/1"""
# """""","""AD 579""","""GRADUATE SEMINAR""","""x""","""""","""1/1"""
# """""","""AD 581""","""DIRECTED READINGS IN MANAGEMENT""","""x""","""x""","""2/22"""
# """""","""AD 585""","""SP.TP.MARKETING RESEARCH CRM&DATA MINING""","""""","""x""","""1/1"""
# """""","""AD 588""","""SP.TP.INFOR.SYST.DIG.BUS.&INFORM.STRAT.""","""""","""x""","""1/1"""
# """""","""AD 593""","""INDUSTRY PROJECT I""","""x""","""x""","""2/22"""
# """""","""AD 594""","""INDUSTRY PROJECT II""","""x""","""x""","""2/22"""
# """""","""AD 595""","""SP. TOP. IN FINANCE & ACCOUNTING""","""""","""x""","""1/1"""
# """""","""AD 596""","""CURRENT ISSUES IN BUSINESS""","""""","""x""","""1/1"""
# """""","""AD 600""","""RESEARCH METHODS""","""x""","""""","""1/1"""
# """""","""AD 601""","""MULTIVARIATE DATA ANALYSIS""","""""","""x""","""1/1"""
# """""","""AD 612""","""THEORY OF FINANCE""","""""","""x""","""1/1"""
# """""","""AD 613""","""THEORY OF FINANCIAL MARKETS&INSTRUMENTS""","""x""","""""","""1/1"""
# """""","""AD 614""","""CORPORATE FINANCE""","""""","""x""","""1/1"""
# """""","""AD 615""","""APPLIED RESEARCH IN FINANCIAL MANAGEMENT""","""x""","""""","""1/1"""
# """""","""AD 620""","""HISTORY OF MANAGEMENT THOUGHT""","""x""","""""","""1/1"""
# """""","""AD 626""","""ORGANIZATIONAL BEHAVIOR:LIFE&EXPERIENCES""","""""","""x""","""1/1"""
# """""","""AD 627""","""ORGANIZATION THEORY""","""x""","""""","""1/1"""
# """""","""AD 640""","""MARKETING THEORY""","""x""","""""","""1/1"""
# """""","""AD 643""","""THEORY OF CONSUMER BEHAVIOR""","""x""","""""","""1/1"""
# """""","""AD 644""","""STRATEGY&MANAGEMENT IN MARKETING SCIENCE""","""""","""x""","""1/1"""
# """""","""AD 660""","""INFORMATION SYSTEMS IN ORGANIZATIONS""","""x""","""""","""1/1"""
# """""","""AD 665""","""CONTEMPORARY ISSUES IN OIM""","""""","""x""","""1/1"""
# """""","""AD 675""","""DIRECTED READINGS IN OIM""","""x""","""x""","""2/1"""
# """""","""AD 676""","""DIRECTED READINGS IN OIM""","""x""","""x""","""2/1"""
# """""","""AD 678""","""DIRECTED READINGS IN OIM""","""x""","""x""","""2/1"""
# """""","""AD 680""","""DIRECTED READINGS IN FINANCE THEORY""","""x""","""x""","""2/4"""
# """""","""AD 681""","""DIRECTED READINGS IN FINANCE THEORY""","""x""","""x""","""2/2"""
# """""","""AD 682""","""DIRECTED READINGS IN FINANCE THEORY""","""x""","""x""","""2/1"""
# """""","""AD 683""","""DIRECTED READINGS IN FINANCE THEORY""","""x""","""x""","""2/2"""
# """""","""AD 684""","""DIRECTED READINGS IN FINANCE THEORY""","""x""","""x""","""2/2"""
# """""","""AD 685""","""DIRECTED READ.IN MGMT.&ORGANIZ.THEORY""","""x""","""""","""1/1"""
# """""","""AD 686""","""DIRECTED READ.IN MGMT.&ORGANIZ.THEORY""","""x""","""""","""1/1"""
# """""","""AD 687""","""DIRECTED READ.IN MGMT.&ORGANIZ. THEORY""","""x""","""x""","""2/1"""
# """""","""AD 688""","""DIRECTED READ.IN MGMT.&ORGANIZ.THEORY""","""x""","""x""","""2/2"""
# """""","""AD 689""","""DIRECTED READ.IN MGMT.&ORGANIZ.THEORY""","""""","""x""","""1/1"""
# """""","""AD 690""","""MASTER THESIS""","""x""","""x""","""2/22"""
# """""","""AD 691""","""DIRECTED READINGS IN MARKETING THEORY""","""x""","""x""","""2/1"""
# """""","""AD 692""","""DIRECTED READINGS IN MARKETING THEORY""","""x""","""x""","""2/1"""
# """""","""AD 693""","""DIRECTED READINGS IN MARKETING THEORY""","""x""","""x""","""2/1"""
# """""","""AD 694""","""DIRECTED READINGS IN MARKETING THEORY""","""""","""x""","""1/1"""
# """""","""AD 696""","""RESEARCH SEMINAR I""","""x""","""""","""1/1"""
# """""","""AD 697""","""RESEARCH SEMINAR II""","""""","""x""","""1/1"""
# """""","""AD 790""","""Ph.D DISSERTATION""","""x""","""x""","""2/22"""
# """ASIA(ASIAN STUDIES)""","""U0 G31""","""""","""U0 G16 I6""","""U0 G20 I7""","""U0 G36 I9"""
# """""","""ASIA501""","""PATHS OF MODERNITY IN ASIA""","""""","""x""","""1/1"""
# """""","""ASIA503""","""TURKEY'S RELATIONS WITH ASIA""","""x""","""""","""1/1"""
# """""","""ASIA508""","""SEMINAR ON THE ASIA-PACIFIC REGION""","""""","""x""","""1/1"""
# """""","""ASIA518""","""HISTORY OF MODERN JAPAN""","""""","""x""","""1/1"""
# """""","""ASIA519""","""HIST.OF JAPAN'S INT. REL.&FOREIGN POLICY""","""x""","""""","""1/1"""
# """""","""ASIA523""","""JAPANESE MANAGEMENT CULTURE&KNOW-HOW""","""x""","""""","""1/1"""
# """""","""ASIA528""","""CHINA'S INTER.REL.&FOREIGN POLICY""","""x""","""""","""1/1"""
# """""","""ASIA529""","""CHINESE ECONOMY&INTERNATIONAL TRADE""","""""","""x""","""1/1"""
# """""","""ASIA532""","""MODERN SOCIETY&GENDER IN CHINA""","""""","""x""","""1/1"""
# """""","""ASIA536""","""SEMINAR ON MODERN KOREA""","""x""","""x""","""2/1"""
# """""","""ASIA540""","""CONTEMP.RUSSIA&CENTRAL ASIA IN WORLD POL""","""""","""x""","""1/1"""
# """""","""ASIA548""","""RESEARCH METHODS""","""x""","""x""","""2/1"""
# """""","""ASIA549""","""PROJECT PAPER""","""""","""x""","""1/1"""
# """""","""ASIA579""","""GRADUATE SEMINAR""","""x""","""x""","""2/1"""
# """""","""ASIA590""","""DIRECTED READINGS IN ASIAN STUDIES I""","""x""","""""","""1/1"""
# """""","""ASIA591""","""DIRECTED READINGS IN ASIAN STUDIES II""","""""","""x""","""1/1"""
# """""","""ASIA592""","""DIRECTED READINGS IN ASIAN STUDIES III""","""x""","""x""","""2/2"""
# """""","""ASIA593""","""DIRECTED READINGS IN ASIA STUDIES IV""","""""","""x""","""1/1"""
# """""","""ASIA690""","""MASTER'S THESIS""","""x""","""x""","""2/1"""
# """""","""ASIL501""","""BEGINNER'S JAPANESE I""","""x""","""""","""1/1"""
# """""","""ASIL502""","""BEGINNER'S JAPANESE II""","""""","""x""","""1/1"""
# """""","""ASIL503""","""INTERMEDIATE JAPANESE I""","""x""","""""","""1/1"""
# """""","""ASIL504""","""INTERMEDIATE JAPANESE II""","""""","""x""","""1/1"""
# """""","""ASIL505""","""ADVANCED JAPANESE I""","""x""","""""","""1/1"""
# """""","""ASIL506""","""ADVANCED JAPANESE II""","""""","""x""","""1/1"""
# """""","""ASIL507""","""BEGINNERS CHINESE I""","""x""","""""","""1/1"""
# """""","""ASIL508""","""BEGINNERS CHINESE II""","""""","""x""","""1/1"""
# """""","""ASIL511""","""ADVANCED CHINESE I""","""x""","""""","""1/1"""
# """""","""ASIL512""","""ADVANCED CHINESE II""","""""","""x""","""1/1"""
# """""","""ASIL515""","""BEGINNERS KOREAN I""","""x""","""""","""1/1"""
# """""","""ASIL517""","""INT.TO CENTRAL ASIAN TURKIC LANGUAGES I""","""""","""x""","""1/1"""
# """ASIA(ASIAN STUDIES WITH THESIS)""","""U0 G31""","""""","""U0 G16 I6""","""U0 G20 I7""","""U0 G36 I9"""
# """""","""ASIA501""","""PATHS OF MODERNITY IN ASIA""","""""","""x""","""1/1"""
# """""","""ASIA503""","""TURKEY'S RELATIONS WITH ASIA""","""x""","""""","""1/1"""
# """""","""ASIA508""","""SEMINAR ON THE ASIA-PACIFIC REGION""","""""","""x""","""1/1"""
# """""","""ASIA518""","""HISTORY OF MODERN JAPAN""","""""","""x""","""1/1"""
# """""","""ASIA519""","""HIST.OF JAPAN'S INT. REL.&FOREIGN POLICY""","""x""","""""","""1/1"""
# """""","""ASIA523""","""JAPANESE MANAGEMENT CULTURE&KNOW-HOW""","""x""","""""","""1/1"""
# """""","""ASIA528""","""CHINA'S INTER.REL.&FOREIGN POLICY""","""x""","""""","""1/1"""
# """""","""ASIA529""","""CHINESE ECONOMY&INTERNATIONAL TRADE""","""""","""x""","""1/1"""
# """""","""ASIA532""","""MODERN SOCIETY&GENDER IN CHINA""","""""","""x""","""1/1"""
# """""","""ASIA536""","""SEMINAR ON MODERN KOREA""","""x""","""x""","""2/1"""
# """""","""ASIA540""","""CONTEMP.RUSSIA&CENTRAL ASIA IN WORLD POL""","""""","""x""","""1/1"""
# """""","""ASIA548""","""RESEARCH METHODS""","""x""","""x""","""2/1"""
# """""","""ASIA549""","""PROJECT PAPER""","""""","""x""","""1/1"""
# """""","""ASIA579""","""GRADUATE SEMINAR""","""x""","""x""","""2/1"""
# """""","""ASIA590""","""DIRECTED READINGS IN ASIAN STUDIES I""","""x""","""""","""1/1"""
# """""","""ASIA591""","""DIRECTED READINGS IN ASIAN STUDIES II""","""""","""x""","""1/1"""
# """""","""ASIA592""","""DIRECTED READINGS IN ASIAN STUDIES III""","""x""","""x""","""2/2"""
# """""","""ASIA593""","""DIRECTED READINGS IN ASIA STUDIES IV""","""""","""x""","""1/1"""
# """""","""ASIA690""","""MASTER'S THESIS""","""x""","""x""","""2/1"""
# """""","""ASIL501""","""BEGINNER'S JAPANESE I""","""x""","""""","""1/1"""
# """""","""ASIL502""","""BEGINNER'S JAPANESE II""","""""","""x""","""1/1"""
# """""","""ASIL503""","""INTERMEDIATE JAPANESE I""","""x""","""""","""1/1"""
# """""","""ASIL504""","""INTERMEDIATE JAPANESE II""","""""","""x""","""1/1"""
# """""","""ASIL505""","""ADVANCED JAPANESE I""","""x""","""""","""1/1"""
# """""","""ASIL506""","""ADVANCED JAPANESE II""","""""","""x""","""1/1"""
# """""","""ASIL507""","""BEGINNERS CHINESE I""","""x""","""""","""1/1"""
# """""","""ASIL508""","""BEGINNERS CHINESE II""","""""","""x""","""1/1"""
# """""","""ASIL511""","""ADVANCED CHINESE I""","""x""","""""","""1/1"""
# """""","""ASIL512""","""ADVANCED CHINESE II""","""""","""x""","""1/1"""
# """""","""ASIL515""","""BEGINNERS KOREAN I""","""x""","""""","""1/1"""
# """""","""ASIL517""","""INT.TO CENTRAL ASIAN TURKIC LANGUAGES I""","""""","""x""","""1/1"""
# """ATA(ATATURK INSTITUTE FOR MODERN TURKISH HISTORY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """AUTO(AUTOMOTIVE ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """BIO(MOLECULAR BIOLOGY & GENETICS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """BIS(BUSINESS INFORMATION SYSTEMS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """BM(BIOMEDICAL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CCS(CRITICAL AND CULTURAL STUDIES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CE(CIVIL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CEM(CONSTRUCTION ENGINEERING AND MANAGEMENT)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CET(EDUCATIONAL TECHNOLOGY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CET(COMPUTER EDUCATION & EDUCATIONAL TECHNOLOGY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CHE(CHEMICAL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CHEM(CHEMISTRY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CMPE(COMPUTER ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """COGS(COGNITIVE SCIENCE)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """CSE(COMPUTATIONAL SCIENCE & ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """EC(ECONOMICS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """ED(EDUCATIONAL SCIENCES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """EE(ELECTRICAL & ELECTRONICS ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """EF(ECONOMICS AND FINANCE)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """ENV(ENVIRONMENTAL SCIENCES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """ENVT(ENVIRONMENTAL TECHNOLOGY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """EQE(EARTHQUAKE ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """ETM(ENGINEERING AND TECHNOLOGY MANAGEMENT)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """FE(FINANCIAL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """FLED(FOREIGN LANGUAGE EDUCATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """GED(GEODESY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """GPH(GEOPHYSICS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """GUID(GUIDANCE & PSYCHOLOGICAL COUNSELING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """HIST(HISTORY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """HUM(HUMANITIES COURSES COORDINATOR)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """IE(INDUSTRIAL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """INCT(INTERNATIONAL COMPETITION AND TRADE)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """INT(CONFERENCE INTERPRETING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """INTT(INTERNATIONAL TRADE)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """INTT(INTERNATIONAL TRADE MANAGEMENT)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """LING(LINGUISTICS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """LL(WESTERN LANGUAGES & LITERATURES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """LS(LEARNING SCIENCES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """MATH(MATHEMATICS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """ME(MECHANICAL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """MECA(MECHATRONICS ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """MIR(INTERNATIONAL RELATIONS:TURKEY;EUROPE AND THE MIDDLE EAST)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """MIR(INTERNATIONAL RELATIONS:TURKEY;EUROPE AND THE MIDDLE EAST WITH THESIS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """MIS(MANAGEMENT INFORMATION SYSTEMS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """PA(FINE ARTS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """PE(PHYSICAL EDUCATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """PHIL(PHILOSOPHY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """PHYS(PHYSICS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """POLS(POLITICAL SCIENCE&INTERNATIONAL RELATIONS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """PRED(PRIMARY EDUCATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """PSY(PSYCHOLOGY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SCED(SECONDARY SCHOOL SCIENCE AND MATHEMATICS EDUCATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SCED(MATHEMATICS AND SCIENCE EDUCATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SCO(SYSTEMS & CONTROL ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SOC(SOCIOLOGY)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SPL(SOCIAL POLICY WITH THESIS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SWE(SOFTWARE ENGINEERING)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """SWE(SOFTWARE ENGINEERING WITH THESIS)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """TK(TURKISH COURSES COORDINATOR)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """TKL(TURKISH LANGUAGE & LITERATURE)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """TR(TRANSLATION AND INTERPRETING STUDIES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """TRM(TOURISM ADMINISTRATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """TRM(SUSTAINABLE TOURISM MANAGEMENT)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """WTR(TRANSLATION)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """XMBE(EXECUTIVE MBA)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
# """YADYOK(SCHOOL OF FOREIGN LANGUAGES)""","""U0 G0""","""""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)""","""U0 G0 ISeries([], Name: Instr., dtype: object)"""
